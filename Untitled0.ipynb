# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Zomato-data-.csv')

# %% [markdown]
# Q1>>..How is the data big

# %%
df.shape
# Out:
# (148, 7)

# %% [markdown]
# q2>.How is the data looks like

# %%
df.head(3)
# Out:
#               name online_order book_table   rate  votes  \
# 0            Jalsa          Yes        Yes  4.1/5    775
# 1   Spice Elephant          Yes         No  4.1/5    787
# 2  San Churro Cafe          Yes         No  3.8/5    918
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet

# %% [markdown]
# Data Analysis
#
# ```
# In data analysis
#
# 1>.Check the Missing value
#
# 2>.Explore Numarical columns
#
# 3>>.Explore the catgorical columns
#
# 4>..Finding the relation betwwen columns
# ```

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
df.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# NOW WE CONVERT THE RATE COLUMNS INTO A FLOAT BY REMOVING DOMINATER

# %%
def handleRate(value):
  value=str(value).split('/')
  value=value[0];
  return float(value)

df['rate']=df['rate'].apply(handleRate)

# %%
df.head(2)
# Out:
#              name online_order book_table  rate  votes  \
# 0           Jalsa          Yes        Yes   4.1    775
# 1  Spice Elephant          Yes         No   4.1    787
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet

# %% [markdown]
# Now explore numarical columns

# %%
df.select_dtypes(include=['number']).columns
# Out:
# Index(['rate', 'votes', 'approx_cost(for two people)'], dtype='object')

# %%
df['rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['rate'].skew()
# Out:
# np.float64(-0.15604931960897167)

# %%
df['rate'].min()
# Out:
# 2.6

# %%
df['rate'].max()
# Out:
# 4.6

# %%
df['rate'].plot(kind='hist',bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['rate'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['rate'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# conclusion
#
# ```
# the majority of the reciving resturent has 3.5 to 4 rating
#
# and data is normal distribution
# ```

# %% [markdown]
# Step 4: Exploring Restaurant Types

# %%
sns.countplot(df['listed_in(type)'])
# Out:
# <Axes: xlabel='count', ylabel='listed_in(type)'>

# %%
df['listed_in(type)'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='listed_in(type)'>

# %%
df['listed_in(type)'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# conclusion
# ```
# # The majority of the resurent fall into the dining table
# ```

# %%
grouped_data = df.groupby('listed_in(type)')['votes'].sum()
result = pd.DataFrame({'votes': grouped_data})
plt.plot(result, c='green', marker='o')
plt.xlabel('Type of restaurant')
plt.ylabel('Votes')
# Out:
# Text(0, 0.5, 'Votes')

# %% [markdown]
# votes by resturent

# %% [markdown]
# Step 5: Identify the Most Voted Restaurant

# %%
max_votes = df['votes'].max()
restaurant_with_max_votes = df.loc[df['votes'] == max_votes, 'name']

print('Restaurant(s) with the maximum votes:')
print(restaurant_with_max_votes)
# Out:
# Restaurant(s) with the maximum votes:
# 38    Empire Restaurant
# Name: name, dtype: object

# %% [markdown]
# Oline Order Avilabiltiy

# %%
sns.countplot(x=df['online_order'])
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %% [markdown]
# the most of the resturent does not accept online order

# %%
# Approximate Cost for Couples

# %%
couple_data=df['approx_cost(for two people)']
sns.countplot(x=couple_data)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %% [markdown]
# The majority of couples prefer restaurants with an approximate cost of 300 rupees
